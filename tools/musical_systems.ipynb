# %%
from freq_table import *

# %%
print(pitch_to_frequency.get('A')[4])
print(pitch_to_frequency.get('A#')[4])
# Out:
# 440.0
# 466.16

# %%
unknown_pitch = 440.0 * (2**(1/12))

# %%
pitch_to_frequency.get('A')[4] * interval_systems.get('semi_tones')
# Out:
# 466.1637615180899

# %%
closest_pitch(unknown_pitch)
# Out:
# 'A#4'

# %%
pitch = 440.0 * (2**(1/12))**3
closest_pitch(pitch)
# Out:
# 'C5'

# %%
(2**11)**(1/12)
# Out:
# 1.8877486253633868

# %%
semitone_intervals = {'m2': 2**(1/12),
             'M2': (2**2)**(1/12),
             'm3': (2**3)**(1/12),
             'M3': (2**4)**(1/12),
             'P4': (2**5)**(1/12),
             'd5': (2**6)**(1/12),
             'P5': (2**7)**(1/12),
             'm6': (2**8)**(1/12),
             'M6': (2**9)**(1/12),
             'm7': (2**10)**(1/12),
             'M7': (2**11)**(1/12)
             }

# %%
pitch_to_frequency.get('A')[4] * semitone_intervals.get('m2')
# Out:
# 466.1637615180899

# %%
interval_systems = {'semi_tones': 2**(1/12),
                    'tri_tones': 2**(1/18),
                    'quarter_tones': 2**(1/24),
                    'sixth_tones': 2**(1/36),   
                    'eigth_tones': 2**(1/48),
                    'twelevth_tones': 2**(1/72),
                    'sixteenth_tones': 2**(1/96),
                    'twenty_fourth_tones': 2**(1/144)
}

# %%
semitone_intervals.get('m2')
# Out:
# 1.0594630943592953

# %%
def make_system(hz, system_type, system_size):
    system = {}
    freq_position = 0
    for p in system_size:
        freq = hz * (system_type)**p
        system['freq_{}'.format(freq_position)] = round(freq, 2)
        freq_position += 1
    return system

# %%
A_440_144_octave = make_system(pitch_to_frequency.get('A')[4], interval_systems.get('twenty_fourth_tones'), range(0,144))

# %%
A_440_144_octave
# Out:
# {'freq_0': 440.0,
#  'freq_1': 442.12,
#  'freq_2': 444.26,
#  'freq_3': 446.4,
#  'freq_4': 448.55,
#  'freq_5': 450.72,
#  'freq_6': 452.89,
#  'freq_7': 455.08,
#  'freq_8': 457.27,
#  'freq_9': 459.48,
#  'freq_10': 461.7,
#  'freq_11': 463.93,
#  'freq_12': 466.16,
#  'freq_13': 468.41,
#  'freq_14': 470.67,
#  'freq_15': 472.94,
#  'freq_16': 475.23,
#  'freq_17': 477.52,
#  'freq_18': 479.82,
#  'freq_19': 482.14,
#  'freq_20': 484.46,
#  'freq_21': 486.8,
#  'freq_22': 489.15,
#  'freq_23': 491.51,
#  'freq_24': 493.88,
#  'freq_25': 496.27,
#  'freq_26': 498.66,
#  'freq_27': 501.07,
#  'freq_28': 503.48,
#  'freq_29': 505.91,
#  'freq_30': 508.36,
#  'freq_31': 510.81,
#  'freq_32': 513.27,
#  'freq_33': 515.75,
#  'freq_34': 518.24,
#  'freq_35': 520.74,
#  'freq_36': 523.25,
#  'freq_37': 525.78,
#  'freq_38': 528.31,
#  'freq_39': 530.86,
#  'freq_40': 533.42,
#  'freq_41': 536.0,
#  'freq_42': 538.58,
#  'freq_43': 541.18,
#  'freq_44': 543.79,
#  'freq_45': 546.42,
# ...

# %%
for k,v in A_440_144_octave.items():
    print(closest_pitch(v))
# Out:
# A4
# A4
# A4
# A4
# A4
# A4
# A4
# A#4
# A#4
# A#4
# A#4
# A#4
# A#4
# A#4
# A#4
# A#4
# A#4
# A#4
# A#4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# B4
# C5
# C5
# C5
# C5
# C5
# C5
# C5
# C5
# C5
# C5
# C5
# C5
# C5
# C#5
# C#5
# C#5
# C#5
# C#5
# C#5
# C#5
# C#5
# C#5
# C#5
# C#5
# D5
# D5
# D5
# D5
# D5
# D5
# D5
# D5
# D5
# D5
# D5
# D5
# D#5
# D#5
# D#5
# D#5
# D#5
# D#5
# D#5
# D#5
# D#5
# D#5
# D#5
# D#5
# E5
# E5
# E5
# E5
# E5
# E5
# E5
# E5
# E5
# E5
# E5
# E5
# E5
# F5
# F5
# F5
# F5
# F5
# F5
# F5
# F5
# F5
# F5
# F5
# F5
# F#5
# F#5
# F#5
# F#5
# F#5
# F#5
# F#5
# F#5
# F#5
# F#5
# F#5
# F#5
# G5
# G5
# G5
# G5
# G5
# G5
# G5
# G5
# G5
# G5
# G5
# G5
# G#5
# G#5
# G#5
# G#5
# G#5
# G#5
# G#5
# G#5
# G#5
# G#5
# G#5
# A5
# A5
# A5
# A5
# A5
# A5

# %%
print('given hz ', A_440_144_octave.get('freq_20'))
f = closest_pitch(A_440_144_octave.get('freq_20'))
print('closest pitch is: ' + f)
diff = find_cent_diff(A_440_144_octave.get('freq_20'),pitch_to_frequency.get(f[0])[int(f[1])])
print('cent offset from '+ f + ' is: ', diff)
# Out:
# given hz  484.46
# closest pitch is: B4
# cent offset from B4 is:  -33.34

# %%
from math import log2
import numpy as np

# %%
# find cents difference
round(1200 * log2(A_440_144_octave.get('freq_20') / A_440_144_octave.get('freq_10')),2)
# Out:
# 83.31

# %%
def find_cent_diff(freq_2, freq_1):
    cents = round(1200 * log2(freq_2/freq_1),2)
    return cents

# %%
find_cent_diff(A_440_144_octave.get('freq_20'), A_440_144_octave.get('freq_10'))
# Out:
# 83.31

# %%
A_440_144_octave.get('freq_20')
# Out:
# 484.46

# %%
A_440_144_octave.get('freq_10')
# Out:
# 461.7

# %%
# transpose cents up
round(461.7 * 2**(round(83.30618446362892,2)/1200),2)
# Out:
# 484.46

# %%
# transpose cents down
round(484.46 * 2**(round(-83.30618446362892,2)/1200),2)
# Out:
# 461.7

# %%
# find closest pitch and cent offset
print('given hz: ', A_440_144_octave.get('freq_20'))
f = closest_pitch(A_440_144_octave.get('freq_20'))
print('closest pitch is: ' + f)
diff = find_cent_diff(A_440_144_octave.get('freq_20'),pitch_to_frequency.get(f[0])[int(f[1])])
print('cent offset from '+ f + ' is: ', diff)
# Out:
# given hz:  484.46
# closest pitch is: B4
# cent offset from B4 is:  -33.34

# %%
pitch_to_frequency.get('A')[4]
freq = round(pitch_to_frequency.get('A')[4] * interval_systems.get('semi_tones')**4,2)
print(freq)
f_ = closest_pitch(pitch_to_frequency.get('A')[4] * interval_systems.get('semi_tones')**4)
print(f_)
print(f_[0:2])
print(int(f_[2]))
find_cent_diff(freq ,pitch_to_frequency.get(f_[0:2])[int(f_[2])])
# Out:
# 554.37
# C#5
# C#
# 5
# 0.0

# %%
def offset_from_closest_pitch(freq):
    print('given hz: ', freq)
    f = closest_pitch(freq)
    print('closest pitch is: ' + f)
    if len(f) == 2:
        diff = find_cent_diff(freq ,pitch_to_frequency.get(f[0])[int(f[1])])
        print('cent offset from '+ f + ' is: ', diff)
        return f, diff
    if len(f) == 3:
        diff = find_cent_diff(freq ,pitch_to_frequency.get(f[0:2])[int(f[2])])
        print('cent offset from '+ f + ' is: ', diff)
        return f, diff

# %%
x = offset_from_closest_pitch(A_440_144_octave.get('freq_20'))
# Out:
# given hz:  484.46
# closest pitch is: B4
# cent offset from B4 is:  -33.34

# %%
log_b(x) = y

# %%
b**y = x

# %%
m2_cents_amnt = (np.log(2**(1/12))/np.log(2))*1200
m2_cents_amnt
# Out:
# 100.00000000000007

# %%
pitch_to_frequency.get('A')[4]*2**-1
# Out:
# 220.0

# %%
from wav_table import *

# %%
A_440 = Hz(pitch_to_frequency.get('A')[4])

# %%
pitch_to_frequency.get('A')[4]*2**2
# Out:
# 1760.0

# %%
ovtser = A_440.make_overtone_series()

# %%
for f in ovtser[1:]:
    print(closest_pitch(f))
# Out:
# A4
# A5
# E6
# A6
# C#7
# E7
# G7
# A7
# B7
# C#8
# D#8
# E8
# F8
# G8
# G#8

# %%
4*-1
# Out:
# -4

# %%
# transpose cents down
round(484.46 * 2**(round((-1*83.30618446362892),2)/1200),2)
# Out:
# 461.7

# %%
pitch_offset = {}
A=0
A_=0
B=0
C=0
C_=0
D=0
D_=0
E=0
F=0
F_=0
G=0
G_=0
for k,v in A_440_144_octave.items():
    
    p_o = offset_from_closest_pitch(v)
    if p_o[0] == 'A4':
        pitch_offset[p_o[0]+'_{}'.format(A)] = p_o[1]
        A+=1
    if p_o[0] == 'A#4':
        pitch_offset[p_o[0]+'_{}'.format(A_)] = p_o[1]
        A_+=1
    if p_o[0] == 'B4':
        pitch_offset[p_o[0]+'_{}'.format(B)] = p_o[1]
        B+=1
    if p_o[0] == 'C5':
        pitch_offset[p_o[0]+'_{}'.format(C)] = p_o[1]
        C+=1
    if p_o[0] == 'C#5':
        pitch_offset[p_o[0]+'_{}'.format(C_)] = p_o[1]
        C_+=1
    if p_o[0] == 'D5':
        pitch_offset[p_o[0]+'_{}'.format(D)] = p_o[1]
        D+=1
    if p_o[0] == 'D#5':
        pitch_offset[p_o[0]+'_{}'.format(D_)] = p_o[1]
        D_+=1
    if p_o[0] == 'E5':
        pitch_offset[p_o[0]+'_{}'.format(E)] = p_o[1]
        E+=1
    if p_o[0] == 'F5':
        pitch_offset[p_o[0]+'_{}'.format(F)] = p_o[1]
        F+=1
    if p_o[0] == 'F#5':
        pitch_offset[p_o[0]+'_{}'.format(F_)] = p_o[1]
        F_+=1
    if p_o[0] == 'G5':
        pitch_offset[p_o[0]+'_{}'.format(G)] = p_o[1]
        G+=1
    if p_o[0] == 'G#5':
        pitch_offset[p_o[0]+'_{}'.format(G_)] = p_o[1]
        G_+=1
    


pitch_offset
# Out:
# given hz:  440.0
# closest pitch is: A4
# cent offset from A4 is:  0.0
# given hz:  442.12
# closest pitch is: A4
# cent offset from A4 is:  8.32
# given hz:  444.26
# closest pitch is: A4
# cent offset from A4 is:  16.68
# given hz:  446.4
# closest pitch is: A4
# cent offset from A4 is:  25.0
# given hz:  448.55
# closest pitch is: A4
# cent offset from A4 is:  33.32
# given hz:  450.72
# closest pitch is: A4
# cent offset from A4 is:  41.67
# given hz:  452.89
# closest pitch is: A4
# cent offset from A4 is:  49.99
# given hz:  455.08
# closest pitch is: A#4
# cent offset from A#4 is:  -41.65
# given hz:  457.27
# closest pitch is: A#4
# cent offset from A#4 is:  -33.33
# given hz:  459.48
# closest pitch is: A#4
# cent offset from A#4 is:  -24.99
# given hz:  461.7
# closest pitch is: A#4
# cent offset from A#4 is:  -16.64
# given hz:  463.93
# closest pitch is: A#4
# cent offset from A#4 is:  -8.3
# given hz:  466.16
# closest pitch is: A#4
# cent offset from A#4 is:  0.0
# ...

# %%
import matplotlib.pyplot as plt
y = list(pitch_offset.values())
x = list(pitch_offset.keys())
plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
ax.plot(x, y)
plt.hlines(y=0, xmin=0, xmax=len(x), colors='r', linestyles='--', lw=2)

plt.show()

# %%
A_440_96_octave = make_system(pitch_to_frequency.get('A')[4], interval_systems.get('sixteenth_tones'), range(0,96))

# %%
pitch_offset_2 = {}
A=0
A_=0
B=0
C=0
C_=0
D=0
D_=0
E=0
F=0
F_=0
G=0
G_=0
for k,v in A_440_96_octave.items():
    
    p_o = offset_from_closest_pitch(v)
    if p_o[0] == 'A4':
        pitch_offset_2[p_o[0]+'_{}'.format(A)] = p_o[1]
        A+=1
    if p_o[0] == 'A#4':
        pitch_offset_2[p_o[0]+'_{}'.format(A_)] = p_o[1]
        A_+=1
    if p_o[0] == 'B4':
        pitch_offset_2[p_o[0]+'_{}'.format(B)] = p_o[1]
        B+=1
    if p_o[0] == 'C5':
        pitch_offset_2[p_o[0]+'_{}'.format(C)] = p_o[1]
        C+=1
    if p_o[0] == 'C#5':
        pitch_offset_2[p_o[0]+'_{}'.format(C_)] = p_o[1]
        C_+=1
    if p_o[0] == 'D5':
        pitch_offset_2[p_o[0]+'_{}'.format(D)] = p_o[1]
        D+=1
    if p_o[0] == 'D#5':
        pitch_offset_2[p_o[0]+'_{}'.format(D_)] = p_o[1]
        D_+=1
    if p_o[0] == 'E5':
        pitch_offset_2[p_o[0]+'_{}'.format(E)] = p_o[1]
        E+=1
    if p_o[0] == 'F5':
        pitch_offset_2[p_o[0]+'_{}'.format(F)] = p_o[1]
        F+=1
    if p_o[0] == 'F#5':
        pitch_offset_2[p_o[0]+'_{}'.format(F_)] = p_o[1]
        F_+=1
    if p_o[0] == 'G5':
        pitch_offset_2[p_o[0]+'_{}'.format(G)] = p_o[1]
        G+=1
    if p_o[0] == 'G#5':
        pitch_offset_2[p_o[0]+'_{}'.format(G_)] = p_o[1]
        G_+=1
    


pitch_offset_2
# Out:
# given hz:  440.0
# closest pitch is: A4
# cent offset from A4 is:  0.0
# given hz:  443.19
# closest pitch is: A4
# cent offset from A4 is:  12.51
# given hz:  446.4
# closest pitch is: A4
# cent offset from A4 is:  25.0
# given hz:  449.63
# closest pitch is: A4
# cent offset from A4 is:  37.48
# given hz:  452.89
# closest pitch is: A4
# cent offset from A4 is:  49.99
# given hz:  456.17
# closest pitch is: A#4
# cent offset from A#4 is:  -37.5
# given hz:  459.48
# closest pitch is: A#4
# cent offset from A#4 is:  -24.99
# given hz:  462.81
# closest pitch is: A#4
# cent offset from A#4 is:  -12.49
# given hz:  466.16
# closest pitch is: A#4
# cent offset from A#4 is:  0.0
# given hz:  469.54
# closest pitch is: A#4
# cent offset from A#4 is:  12.51
# given hz:  472.94
# closest pitch is: A#4
# cent offset from A#4 is:  25.0
# given hz:  476.37
# closest pitch is: A#4
# cent offset from A#4 is:  37.51
# given hz:  479.82
# closest pitch is: A#4
# cent offset from A#4 is:  50.0
# ...

# %%
y = list(pitch_offset_2.values())
x = list(pitch_offset_2.keys())
plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
ax.plot(x, y)
plt.hlines(y=0, xmin=0, xmax=len(x), colors='r', linestyles='--', lw=2)

plt.show()

# %%
A_440_12_octave = make_system(pitch_to_frequency.get('A')[4], interval_systems.get('semi_tones'), range(0,12))

# %%
pitch_offset_3 = {}
count = 0
for k,v in A_440_12_octave.items():
    
    p_o = offset_from_closest_pitch(v)
    pitch_offset_3[p_o[0]+'_{}'.format(count)] = p_o[1]
    count +=1
 


pitch_offset_3
# Out:
# given hz:  440.0
# closest pitch is: A4
# cent offset from A4 is:  0.0
# given hz:  466.16
# closest pitch is: A#4
# cent offset from A#4 is:  0.0
# given hz:  493.88
# closest pitch is: B4
# cent offset from B4 is:  0.0
# given hz:  523.25
# closest pitch is: C5
# cent offset from C5 is:  0.0
# given hz:  554.37
# closest pitch is: C#5
# cent offset from C#5 is:  0.0
# given hz:  587.33
# closest pitch is: D5
# cent offset from D5 is:  0.0
# given hz:  622.25
# closest pitch is: D#5
# cent offset from D#5 is:  0.0
# given hz:  659.26
# closest pitch is: E5
# cent offset from E5 is:  0.0
# given hz:  698.46
# closest pitch is: F5
# cent offset from F5 is:  0.0
# given hz:  739.99
# closest pitch is: F#5
# cent offset from F#5 is:  0.0
# given hz:  783.99
# closest pitch is: G5
# cent offset from G5 is:  0.0
# given hz:  830.61
# closest pitch is: G#5
# cent offset from G#5 is:  0.0
# {'A4_0': 0.0,
#  'A#4_1': 0.0,
#  'B4_2': 0.0,
#  'C5_3': 0.0,
#  'C#5_4': 0.0,
#  'D5_5': 0.0,
# ...

# %%
#convert freq to midi notation
round(69 + 12*log2(pitch_to_frequency.get('A#')[4]/440))
# Out:
# 70

# %%
# covert midi notation to frequency
round(2**((70-69)/12)*440, 2)
# Out:
# 466.16

# %%
pitch_to_frequency.get('A#')[4]
# Out:
# 466.16

# %%
C_neg1_12_System = make_system(8.1758, interval_systems.get('semi_tones'), range(0,128))

# %%
C_neg1_12_System
# Out:
# {'freq_0': 8.18,
#  'freq_1': 8.66,
#  'freq_2': 9.18,
#  'freq_3': 9.72,
#  'freq_4': 10.3,
#  'freq_5': 10.91,
#  'freq_6': 11.56,
#  'freq_7': 12.25,
#  'freq_8': 12.98,
#  'freq_9': 13.75,
#  'freq_10': 14.57,
#  'freq_11': 15.43,
#  'freq_12': 16.35,
#  'freq_13': 17.32,
#  'freq_14': 18.35,
#  'freq_15': 19.45,
#  'freq_16': 20.6,
#  'freq_17': 21.83,
#  'freq_18': 23.12,
#  'freq_19': 24.5,
#  'freq_20': 25.96,
#  'freq_21': 27.5,
#  'freq_22': 29.14,
#  'freq_23': 30.87,
#  'freq_24': 32.7,
#  'freq_25': 34.65,
#  'freq_26': 36.71,
#  'freq_27': 38.89,
#  'freq_28': 41.2,
#  'freq_29': 43.65,
#  'freq_30': 46.25,
#  'freq_31': 49.0,
#  'freq_32': 51.91,
#  'freq_33': 55.0,
#  'freq_34': 58.27,
#  'freq_35': 61.74,
#  'freq_36': 65.41,
#  'freq_37': 69.3,
#  'freq_38': 73.42,
#  'freq_39': 77.78,
#  'freq_40': 82.41,
#  'freq_41': 87.31,
#  'freq_42': 92.5,
#  'freq_43': 98.0,
#  'freq_44': 103.83,
#  'freq_45': 110.0,
#  'freq_46': 116.54,
#  'freq_47': 123.47,
# ...

# %%
import wave

CHANNELS = 1
swidth = 2
# slow down and speed up wav files 
# if the number is under 1 it is slower, if the number is above 1, it is faster
Change_RATE = 1.3

spf = wave.open('stretched.wav', 'rb')
RATE=spf.getframerate()
signal = spf.readframes(-1)

wf = wave.open('changed.wav', 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(swidth)
wf.setframerate(RATE*Change_RATE)
wf.writeframes(signal)
wf.close()

# %%
import wave

# to time stretch recording (pitch is not as affected)
# less that 1 speeds up the audio, greater than 1 slows down the audio
def main():
    stretch('changed.wav', .7)

def stretch( fname,  factor ):

    infile=wave.open( fname, 'rb')
    rate= infile.getframerate()
    channels=infile.getnchannels()
    swidth=infile.getsampwidth()
    nframes= infile.getnframes()
    audio_signal= infile.readframes(nframes)
    outfile = wave.open('stretched.wav', 'wb')
    outfile.setnchannels(channels)
    outfile.setsampwidth(swidth)
    outfile.setframerate(rate/factor)
    outfile.writeframes(audio_signal)
    outfile.close()
    return;

main()

# %%
import librosa

# %%
y, sr = librosa.load('/Volumes/S190813/Creative/Music/Wonder pt. 1/PhraseA/PHRASE.WAV')
y_shifted = librosa.effects.pitch_shift(y, sr, n_steps=15, bins_per_octave=48)

# %%
librosa.output.write_wav('lib_shift.wav', y_shifted, sr)

# %%
import wave
import numpy as np

# %%
# this function isn't that great
# pitch up
wr = wave.open('/Volumes/S190813/Creative/Music/Wonder pt. 1/PhraseA/PHRASE.WAV', 'r')
# Set the parameters for the output file.
par = list(wr.getparams())
par[3] = 0  # The number of samples will be set by writeframes.
par = tuple(par)
ww = wave.open('pitch1.wav', 'w')
ww.setparams(par)
fr = 20
sz = wr.getframerate()//fr  # Read and process 1/fr second at a time.
# A larger number for fr means less reverb.
c = int(wr.getnframes()/sz)  # count of the whole file
shift = round((440 * semitone_intervals.get('P5')) - 440)//fr  # shifting up 26hz (roughly a M3)
for num in range(c):
    da = np.fromstring(wr.readframes(sz), dtype=np.int16)
    left, right = da[0::2], da[1::2]  # left and right channel
    lf, rf = np.fft.rfft(left), np.fft.rfft(right)
    lf, rf = np.roll(lf, shift), np.roll(rf, shift)
    lf[0:shift], rf[0:shift] = 0, 0
    nl, nr = np.fft.irfft(lf), np.fft.irfft(rf)
    ns = np.column_stack((nl, nr)).ravel().astype(np.int16)
    ww.writeframes(ns.tostring())
wr.close()
ww.close()

# %%
# distance in hz of a minor 2nd interval
round((440 * semitone_intervals.get('m2')) - 440,2)
# Out:
# 26.16

# %%
def distance_of_interval(interval):
    dist = round((440 * interval) - 440,2)
    return dist

# %%
distance_of_interval(semitone_intervals.get('m7'))
# Out:
# 343.99
