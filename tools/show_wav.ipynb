# %%
import numpy as np 
import scipy
import matplotlib.pyplot as plt
from scipy.io.wavfile import read, write
from scipy.fftpack import fft
import numpy as np

# %%
# Number of sample points
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = np.sin(440.0 * 2.0*np.pi*x) + 0.5*np.sin(220.0 * 2.0*np.pi*x)
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)

plt.plot(xf, 2.0/N * np.abs(yf[0:int(N/2)]))
plt.grid()
plt.show()

# %%
def fft_plot_wav(wav, sr, xlimit=None, ylimit=None):
    n = len(wav)
    T = 1/sr
    yf = fft(wav)
    xf = np.linspace(0.0, 1.0/(2.0*T), n/2)
    fig, ax = plt.subplots()
    ax.plot(xf, 2.0/n * np.abs(yf[:n//2]))
    plt.xlim(xlimit[0], xlimit[1])
    plt.ylim(ylimit[0], ylimit[1])
    plt.grid()
    plt.xlabel('Frequency --- >')
    plt.ylabel('Magnitude')
    return plt.show()

# %%
sr, wav = read('/Volumes/S200408/backup/S190813/Coding/wav_utilities/upside_down.wav')
xlimit = [5000, 5200]
ylimit = [0.000, 0.0015]
fft_plot(wav, sr, xlimit, ylimit)

# %%
sr, wav = read('/Volumes/S200408/backup/S190813/Coding/wav_utilities/wav_files/pair_0.wav')
xlimit = [0,1000]
ylimit = [0,175]
fft_plot(wav, sr, xlimit, ylimit)

# %%
def fft_plot_wav(wav, sr, xlimit=None, ylimit=None):
    n = len(wav)
    T = 1/sr
    yf = fft(wav)
    xf = np.linspace(0.0, 1.0/(2.0*T), n/2)
    fig, ax = plt.subplots()
    ax.plot(xf, 2.0/n * np.abs(yf[:n//2]))
    plt.grid()
    plt.xlabel('Frequency --- >')
    plt.ylabel('Magnitude')
    return plt.show()
