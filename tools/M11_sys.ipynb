# %% [markdown]
# ## Collaborating with GlassAI

# %%
from wav_table import *

# %%
wav = '/Volumes/S200408/backup/S190813/Coding/wav_utilities/wav_utilities/tools/pg_2_generated_song_1.wav'

# %%
# send GLassAI through Sequential Algorithm
reverse_audio_2(wav, 'r.wav')
set_to_mono(wav, 'rm.wav')
glass_params, glass_bytes = input_for_delay('rm.wav')
delay_wave(mode_4(glass_bytes,
                  glass_params,
                  offset_ms=150, 
                  factor=0.5, 
                  num=3),
                  glass_params, 
                  'delay.wav',
                  'delay_150ms_0.5f_3n')
stretch_algorithm_4('delay_delay_150ms_0.5f_3n.wav',
                     2,
                     'rmdt.wav')
glass_params, glass_bytes = input_for_delay('rmdt.wav')
delay_wave(mode_4(glass_bytes,
                  glass_params,
                  offset_ms=250, 
                  factor=0.5, 
                  num=6),
                  muzak_params, 
                  'delay.wav',
                  'delay_250ms_0.5f_6n')
# Out:
# desrever won si oidua eruoy
# /Volumes/S200408/backup/S190813/Coding/wav_utilities/wav_utilities/tools/pg_2_generated_song_1.wav is now set to mono as rm.wav
# strech_algorithim_4 complete

# %%
reverse_audio_1('delay_delay_250ms_0.5f_6n.wav', 're_delay_delay_250ms_0.5f_6n.wav')
# Out:
# desrever won si oidua eruoy

# %%
# layer both the reverse and non reversed out put of the effects chain
wave_list = ['delay_delay_250ms_0.5f_6n.wav',
             're_delay_delay_250ms_0.5f_6n.wav'
]
stack_wav(wave_list, 'glass_stacked_reverse_delays.wav')

# %%
wav = '/Volumes/S200408/backup/S190813/Coding/wav_utilities/wav_utilities/tools/wav_files/glass_stacked_reverse_delays.wav'

# %%
stretch_algorithim_2(wav, 2, 'slow_glass.wav')
# Out:
# stretch_algorithim_2 complete

# %%
show_signal('slow_glass.wav')
